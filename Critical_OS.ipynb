# %%
# !cat /etc/*release
# $(lsb_release -cs)

# %cd /
# !rm -r ~/Linux_Debian/
# !git clone https://github.com/criticalsoft/Linux_Debian.git ~/Linux_Debian/
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=22.04
# DISTRIB_CODENAME=jammy
# DISTRIB_DESCRIPTION="Ubuntu 22.04.3 LTS"
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy
# /
# rm: cannot remove '/root/Linux_Debian/': No such file or directory
# Cloning into '/root/Linux_Debian'...
# remote: Enumerating objects: 1834, done.
# remote: Counting objects: 100% (1833/1833), done.
# remote: Compressing objects: 100% (1513/1513), done.
# remote: Total 1834 (delta 261), reused 1810 (delta 260), pack-reused 1
# Receiving objects: 100% (1834/1834), 96.87 MiB | 46.70 MiB/s, done.
# Resolving deltas: 100% (261/261), done.

# %%
# %cd ~/Linux_Debian/
# !sudo chmod 777 ./ -R
# !ls -la

# !rm -r ~/Critical_OS/
# !./Live_Build_Ubuntu.sh
# Out:
# /root/Linux_Debian
# total 1480
# drwxrwxrwx 15 root root    4096 Dec  3 05:55 .
# drwx------  1 root root    4096 Dec  3 05:55 ..
# drwxrwxrwx  6 root root    4096 Dec  3 05:55 1_Driver
# drwxrwxrwx  7 root root    4096 Dec  3 05:55 2_System
# drwxrwxrwx  5 root root    4096 Dec  3 05:55 3_WorkFlow
# drwxrwxrwx  8 root root    4096 Dec  3 05:55 4_Theme
# drwxrwxrwx  9 root root    4096 Dec  3 05:55 5_File_Terminal
# drwxrwxrwx 11 root root    4096 Dec  3 05:55 6_Text_Browser
# drwxrwxrwx 10 root root    4096 Dec  3 05:55 7_Player_Editor
# drwxrwxrwx  9 root root    4096 Dec  3 05:55 8_Recorder_Convertor
# -rwxrwxrwx  1 root root    2341 Dec  3 05:55 ALL.sh
# drwxrwxrwx  6 root root    4096 Dec  3 05:55 ANTIVIRUS
# -rwxrwxrwx  1 root root     202 Dec  3 05:55 Colab_Build.desktop
# -rwxrwxrwx  1 root root  270398 Dec  3 05:55 .cover.ico
# -rwxrwxrwx  1 root root   28345 Dec  3 05:55 Critical_OS.ipynb
# -rwxrwxrwx  1 root root      86 Dec  3 05:55 desktop.ini
# ...

# %%
from google.colab import drive
drive.mount('~/drive')

# !cp ~/Critical_OS/live-image-amd64.txt ~/drive/MyDrive/Critical_OS/
# !cp ~/Critical_OS/live-image-amd64.img ~/drive/MyDrive/Critical_OS/
# Out:
# Drive already mounted at /root/drive; to attempt to forcibly remount, call drive.mount("/root/drive", force_remount=True).
# sha256sum: /root/Critical_OS/live-image-amd64.img: No such file or directory
# cp: cannot stat '/root/Critical_OS/live-image-amd64.txt': No such file or directory
# cp: cannot stat '/root/Critical_OS/live-image-amd64.img': No such file or directory
